# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
url = 'db/Journalists.csv'
journalists = pd.read_csv(url, header=0)
journalists
# Out:
#                            Name           Role            Motive   Sex  \
# 0                    Abay Hailu     Journalist  Motive Confirmed  Male
# 1          Abd al-Karim al-Ezzo     Journalist  Motive Confirmed  Male
# 2            Abdallah Bouhachek     Journalist  Motive Confirmed  Male
# 3     Abdel Aziz Mahmoud Hasoun     Journalist  Motive Confirmed  Male
# 4           Abdel Karim al-Oqda     Journalist  Motive Confirmed  Male
# ...                         ...            ...               ...   ...
# 1575           Unidentified (3)  Media Workers               NaN   NaN
# 1576           Unidentified (4)  Media Workers               NaN   NaN
# 1577            Waqas Aziz Khan  Media Workers               NaN   NaN
# 1578              Yasser Khatab  Media Workers               NaN   NaN
# 1579         Ziad Tarek al-Dibo  Media Workers               NaN   NaN
#
#              Date Killed Year of Death Month of Death Country Killed  \
# ...

# %%
journalists.head()
# Out:
#                         Name        Role            Motive   Sex  \
# 0                 Abay Hailu  Journalist  Motive Confirmed  Male
# 1       Abd al-Karim al-Ezzo  Journalist  Motive Confirmed  Male
# 2         Abdallah Bouhachek  Journalist  Motive Confirmed  Male
# 3  Abdel Aziz Mahmoud Hasoun  Journalist  Motive Confirmed  Male
# 4        Abdel Karim al-Oqda  Journalist  Motive Confirmed  Male
#
#           Date Killed Year of Death Month of Death Country Killed  \
# 0   February  9, 1998          1998       February       Ethiopia
# 1   December 21, 2012          2012       December          Syria
# 2   February 10, 1996          1996       February        Algeria
# 3  September  5, 2013          2013      September          Syria
# 4  September 19, 2012          2012      September          Syria
#
#             Organization Nationality  ... Local/Foreign        Source of Fire  \
# 0                 Agiere    Ethiopia  ...         Local  Government Officials
# ...

# %%
journalists.head(30)
# Out:
#                                 Name        Role            Motive   Sex  \
# 0                         Abay Hailu  Journalist  Motive Confirmed  Male
# 1               Abd al-Karim al-Ezzo  Journalist  Motive Confirmed  Male
# 2                 Abdallah Bouhachek  Journalist  Motive Confirmed  Male
# 3          Abdel Aziz Mahmoud Hasoun  Journalist  Motive Confirmed  Male
# 4                Abdel Karim al-Oqda  Journalist  Motive Confirmed  Male
# 5               Abdel Karim al-Rubai  Journalist  Motive Confirmed  Male
# 6           Abdel Karim Nazir Ismail  Journalist  Motive Confirmed  Male
# 7           Abdel Sattar Abdel Karim  Journalist  Motive Confirmed  Male
# 8                 Abdelhamid Benmeni  Journalist  Motive Confirmed  Male
# 9                Abdelhamid Yahiaoui  Journalist  Motive Confirmed  Male
# 10                Abdelkader Hireche  Journalist  Motive Confirmed  Male
# 11              Abderrahmane Chergou  Journalist  Motive Confirmed  Male
# ...

# %%
journalists.shape
# Out:
# (1580, 24)

# %%
journalists.dtypes
# https://stackoverflow.com/questions/41143969/can-not-convert-column-type-from-object-to-str-in-python-dataframe
# Out:
# Name                     object
# Role                     object
# Motive                   object
# Sex                      object
# Date Killed              object
# Year of Death            object
# Month of Death           object
# Country Killed           object
# Organization             object
# Nationality              object
# Medium                   object
# Job                      object
# Coverage                 object
# Freelance                object
# Local/Foreign            object
# Source of Fire           object
# Type of Death            object
# Impunity (for Murder)    object
# Taken Captive            object
# Threatened               object
# Tortured                 object
# Profile on CPJ           object
# Image                    object
# Description              object
# dtype: object
